# %% [markdown]
# # Question 1

# %%
# Step 1:
import pandas as pd
import numpy as np

# %%
#Step 2,3:
url= 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users= pd.read_csv(url, sep='|', index_col='user_id')

# %%
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
#Step 4:
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Step 5:
male_female_Ratio = users.pivot_table(index='occupation', columns='gender', aggfunc='size')
male_female_Ratio
# Out:
# gender            F      M
# occupation
# administrator  36.0   43.0
# artist         13.0   15.0
# doctor          NaN    7.0
# educator       26.0   69.0
# engineer        2.0   65.0
# entertainment   2.0   16.0
# executive       3.0   29.0
# healthcare     11.0    5.0
# homemaker       6.0    1.0
# lawyer          2.0   10.0
# librarian      29.0   22.0
# marketing      10.0   16.0
# none            4.0    5.0
# other          36.0   69.0
# programmer      6.0   60.0
# retired         1.0   13.0
# salesman        3.0    9.0
# scientist       3.0   28.0
# student        60.0  136.0
# technician      1.0   26.0
# writer         19.0   26.0

# %%
sums= male_female_Ratio[['F', 'M']].sum(axis=1)
male_female_Ratio['add column for male Ratio'] = round(100 * male_female_Ratio['M'] / sums , 1)
x1 =male_female_Ratio['add column for male Ratio']
x1.sort_values(ascending=False)
# Out:
# occupation
# doctor           100.0
# engineer          97.0
# technician        96.3
# retired           92.9
# programmer        90.9
# executive         90.6
# scientist         90.3
# entertainment     88.9
# lawyer            83.3
# salesman          75.0
# educator          72.6
# student           69.4
# other             65.7
# marketing         61.5
# writer            57.8
# none              55.6
# administrator     54.4
# artist            53.6
# librarian         43.1
# healthcare        31.2
# homemaker         14.3
# Name: add column for male Ratio, dtype: float64

# %%
# Step 6:
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#Step 7:
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8:
a=users.groupby(['occupation', 'gender']).count()
b=users.groupby('occupation').count()
a= a.drop(columns='zip_code')
b= b.drop(columns='zip_code')
c=(a/b)*100
c= c.drop(columns='gender')
c
# Out:
#                              age
# occupation    gender
# administrator F        45.569620
#               M        54.430380
# artist        F        46.428571
#               M        53.571429
# doctor        M       100.000000
# educator      F        27.368421
#               M        72.631579
# engineer      F         2.985075
#               M        97.014925
# entertainment F        11.111111
#               M        88.888889
# executive     F         9.375000
#               M        90.625000
# healthcare    F        68.750000
#               M        31.250000
# homemaker     F        85.714286
#               M        14.285714
# lawyer        F        16.666667
#               M        83.333333
# librarian     F        56.862745
#               M        43.137255
# marketing     F        38.461538
#               M        61.538462
# none          F        44.444444
#               M        55.555556
# other         F        34.285714
# ...

# %% [markdown]
# # Question 2

# %%
# Step 1,2,3
euro12=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %%
# Step 4:
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Step 5:
len(euro12['Team'].unique())
# Out:
# 16

# %%
#Step 6:
len(euro12.columns)
# Out:
# 35

# %%
#Step 7:
discipline=pd.DataFrame(euro12, columns=['Team','Yellow Cards', 'Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8:
discipline.sort_values(['Red Cards','Yellow Cards'], ascending=[True, True])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
#Step 9:
discipline.groupby('Team')['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9
# Czech Republic          7
# Denmark                 4
# England                 5
# France                  6
# Germany                 4
# Greece                  9
# Italy                  16
# Netherlands             5
# Poland                  7
# Portugal               12
# Republic of Ireland     6
# Russia                  6
# Spain                  11
# Sweden                  7
# Ukraine                 5
# Name: Yellow Cards, dtype: int64

# %%
#STep 10:
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#Step 11:
euro12[euro12.Team.str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Step 12:
euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 13:
euro12.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 14:
euro12.loc[[3,7,12] , ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3:

# %%
first_random = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
second_random = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
third_random = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

# %%
Housing = pd.concat([first_random, second_random, third_random], axis=1)
Housing
# Out:
#     0  1      2
# 0   3  2  18688
# 1   1  3  15845
# 2   1  2  24988
# 3   3  3  27535
# 4   4  2  20554
# .. .. ..    ...
# 95  2  1  21675
# 96  2  3  29404
# 97  3  3  13383
# 98  3  3  12430
# 99  1  2  18640
#
# [100 rows x 3 columns]

# %%
Housing.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
Housing
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            18688
# 1       1       3            15845
# 2       1       2            24988
# 3       3       3            27535
# 4       4       2            20554
# ..    ...     ...              ...
# 95      2       1            21675
# 96      2       3            29404
# 97      3       3            13383
# 98      3       3            12430
# 99      1       2            18640
#
# [100 rows x 3 columns]

# %%
bigcolumn = pd.DataFrame(pd.concat([first_random, second_random, third_random], axis=0))
bigcolumn
# Out:
#         0
# 0       3
# 1       1
# 2       1
# 3       3
# 4       4
# ..    ...
# 95  21675
# 96  29404
# 97  13383
# 98  12430
# 99  18640
#
# [300 rows x 1 columns]

# %%
bigcolumn.iloc[95:150,]
# Out:
#     0
# 95  2
# 96  2
# 97  3
# 98  3
# 99  1
# 0   2
# 1   3
# 2   2
# 3   3
# 4   2
# 5   2
# 6   1
# 7   2
# 8   2
# 9   3
# 10  3
# 11  1
# 12  2
# 13  2
# 14  1
# 15  2
# 16  3
# 17  1
# 18  1
# 19  3
# 20  3
# 21  3
# 22  2
# 23  3
# 24  2
# 25  3
# 26  1
# 27  2
# 28  1
# 29  2
# 30  3
# 31  2
# 32  1
# 33  2
# 34  2
# 35  2
# 36  3
# 37  3
# 38  3
# 39  3
# 40  2
# 41  2
# 42  2
# 43  2
# 44  3
# 45  2
# 46  3
# 47  3
# 48  1
# 49  2

# %%
bigcolumn.reset_index(inplace = True) 
bigcolumn.iloc[95:200,]
# Out:
#      index  0
# 95      95  2
# 96      96  2
# 97      97  3
# 98      98  3
# 99      99  1
# ..     ... ..
# 195     95  1
# 196     96  3
# 197     97  3
# 198     98  3
# 199     99  2
#
# [105 rows x 2 columns]

# %% [markdown]
# # Question 4:

# %%
import datetime

# %%
data=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',sep="\s+",parse_dates=[[0,1,2]])
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %%
def fix(y):
  year=y.year-100 if y.year > 1979 else y.year
  return datetime.date(year,y.month,y.day)
data['Yr_Mo_Dy']=data['Yr_Mo_Dy'].apply(fix)
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
data['Yr_Mo_Dy']=pd.to_datetime(data['Yr_Mo_Dy'])
data=data.set_index('Yr_Mo_Dy')
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# ...

# %%
#Step 6:
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#Step 7:
data.shape[0]-data.isnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
#Step 8:
Mnws= data.mean()
Mnws.mean()
# Out:
# 10.227982360836924

# %%
#Step 9:
loc_stats=pd.DataFrame()
loc_stats['min']=data.min()
loc_stats['max']=data.max()
loc_stats['mean']=data.mean()
loc_stats['std']=data.std()
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %%
#Step 10:
day_stats=pd.DataFrame()
day_stats['min']=data.min(axis=1)
day_stats['max']=data.max(axis=1)
day_stats['mean']=data.mean(axis=1)
day_stats['std']=data.std(axis=1)

# %%
day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
#Step 11:

data['date']=data.index
data['month']=data['date'].apply(lambda date:date.month)
data['year']=data['date'].apply(lambda date:date.year)
data['day']=data['date'].apply(lambda date:date.day)
jan_wind_spd=data.query('month==1')
jan_wind_spd
jan_wind_spd.loc[:,'RPT':'MAL'].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
#Step 12:
data.query('month == 1 and day == 1')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1962-01-01   9.29   3.42  11.54   3.50   2.21   1.96  10.41   2.79   3.54
# 1963-01-01  15.59  13.62  19.79   8.38  12.25  10.00  23.45  15.71  13.59
# 1964-01-01  25.80  22.13  18.21  13.25  21.29  14.79  14.12  19.58  13.25
# 1965-01-01   9.54  11.92   9.00   4.38   6.08   5.21  10.25   6.08   5.71
# 1966-01-01  22.04  21.50  17.08  12.75  22.17  15.59  21.79  18.12  16.66
# 1967-01-01   6.46   4.46   6.50   3.21   6.67   3.79  11.38   3.83   7.71
# 1968-01-01  30.04  17.88  16.25  16.25  21.79  12.54  18.16  16.62  18.75
# 1969-01-01   6.13   1.63   5.41   1.08   2.54   1.00   8.50   2.42   4.58
# 1970-01-01   9.59   2.96  11.79   3.42   6.13   4.08   9.00   4.46   7.29
# 1971-01-01   3.71   0.79   4.71   0.17   1.42   1.04   4.63   0.75   1.54
# ...

# %%
#Step 13.
data.query('day == 1')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-02-01  14.25  15.12   9.04   5.88  12.08   7.17  10.17   3.63   6.50
# 1961-03-01  12.67  13.13  11.79   6.42   9.79   8.54  10.25  13.29    NaN
# 1961-04-01   8.38   6.34   8.33   6.75   9.33   9.54  11.67   8.21  11.21
# 1961-05-01  15.87  13.88  15.37   9.79  13.46  10.17   9.96  14.04   9.75
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-08-01  19.33  15.09  20.17   8.83  12.62  10.41   9.33  12.33   9.50
# 1978-09-01   8.42   6.13   9.87   5.25   3.21   5.71   7.25   3.50   7.33
# 1978-10-01   9.50   6.83  10.50   3.88   6.13   4.58   4.21   6.50   6.38
# 1978-11-01  13.59  16.75  11.25   7.08  11.04   8.33   8.17  11.29  10.75
# 1978-12-01  21.29  16.29  24.04  12.79  18.21  19.29  21.54  17.21  16.71
#
#               CLO    BEL    MAL       date  month  year  day
# ...

# %%
#Step 14:
data.groupby(data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %%
#Step 15:
per_week = data.resample('W').agg(['min','max','mean','std'])
per_week.loc[per_week.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# # Question 5:

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipotle = pd.read_csv(url, sep = '\t')

# %%
chipotle.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipotle.shape[0]
# Out:
# 4622

# %%
len(chipotle.columns)
# Out:
# 5

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
Most_ordered= chipotle.item_name.value_counts()
Most_ordered.head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
len(chipotle['item_name'].unique())
# Out:
# 50

# %%
Most_ord_choice_description =chipotle.choice_description.value_counts()
Most_ord_choice_description.head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
chipotle.quantity.sum()
# Out:
# 4972

# %%
#Step 13:

def turn(x):
    return float(x[1:-1])
chipotle.item_price = chipotle.item_price.apply(turn)
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipotle.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipotle.item_price.dtypes
# Out:
# dtype('float64')

# %%
#Step 14. How much was the revenue for the period in the dataset?
chipotle.item_price.sum()
# Out:
# 34500.16

# %%
#Step 15:
len(chipotle['order_id'].value_counts())
# Out:
# 1834

# %%
#Step 16. 
avrg_revn = chipotle.groupby(['order_id']).sum()
avrg_revn

# %%
avrg_revn['item_price'].mean()
# Out:
# 18.81142857142869

# %%
#Step 17:
different_items= len(chipo['item_name'].unique())
different_items
# Out:
# 50

# %% [markdown]
# # Question 6:

# %%
#Importing libraries for visualization
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
USMD= pd.read_csv('C:\\Users\\hasee\\Desktop\\classes\\Data Programming - BDAT 1004 - 02\\Assignments\\Program set3\\us-marriages-divorces-1867-2014.csv')

# %%
USMD
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
USMD.plot.line(x='Year', y={'Marriages','Divorces'})
plt.title(' number of marriages and divorces per capita in the U.S. between 1867 and 2014', fontsize=10, color = 'Blue',fontweight='bold')
# Out:
# Text(0.5, 1.0, ' number of marriages and divorces per capita in the U.S. between 1867 and 2014')

# %% [markdown]
# # Question 7:

# %%
USMD.plot.bar(x='Year', y={'Marriages','Divorces'})
plt.xlabel('year', fontsize=14)
plt.title('number of marriages and divorces per capita in the U.S. between 1867 and 2014', fontsize=16, color = 'Green',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'number of marriages and divorces per capita in the U.S. between 1867 and 2014')

# %% [markdown]
# # Question 8:

# %%
actr_kill=pd.read_csv('C:\\Users\\hasee\\Desktop\\classes\\Data Programming - BDAT 1004 - 02\\Assignments\\Program set3\\actor_kill_counts.csv')

# %%
actr_kill
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
ak= actr_kill.sort_values(['Count','Actor'], ascending=[True, False])
ak
# Out:
#                    Actor  Count
# 9          Wesley Snipes    193
# 3             Clive Owen    194
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 2         Clint Eastwood    207
# 8    Tomisaburo Wakayama    226
# 4         Dolph Lundgren    239
# 7     Sylvester Stallone    267
# 1           Chow Yun-Fat    295
# 0  Arnold Schwarzenegger    369

# %%
ak.plot.barh(x='Actor', y='Count')
plt.title('deadliest actors in Hollywood.', fontsize=18, color = 'Magenta')
# Out:
# Text(0.5, 1.0, 'deadliest actors in Hollywood.')

# %% [markdown]
# # Question 9:

# %%
rom_emp=pd.read_csv('C:\\Users\\hasee\\Desktop\\classes\\Data Programming - BDAT 1004 - 02\\Assignments\\Program set3\\roman-emperor-reigns.csv')
rom_emp
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
rom_emp = rom_emp[(rom_emp == 'Assassinated').any(axis=1)]
rom_emp
df = pd.DataFrame({'mass': rom_emp['Length_of_Reign'],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=rom_emp['Emperor'])
plot = rom_emp.plot.pie(y='mass', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-7307565479ac> in <module>
#       1 rom_emp = rom_emp[(rom_emp == 'Assassinated').any(axis=1)]
#       2 rom_emp
# ----> 3 df = pd.DataFrame({'mass': rom_emp['Length_of_Reign'],
#       4                    'radius': [2439.7, 6051.8, 6378.1]},
#       5                   index=rom_emp['Emperor'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
# ...

# %% [markdown]
# # Question 10

# %%
relation=pd.read_csv('C:\\Users\\hasee\\Desktop\\classes\\Data Programming - BDAT 1004 - 02\\Assignments\\Program set3\\arcade-revenue-vs-cs-doctorates.csv')
relation
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
relation.plot.scatter(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', c='DarkBlue')
plt.title('relationship between the total revenue earned by arcades and the number of Computer Science PhDs', fontsize=16, color = 'Green')
# Out:
# Text(0.5, 1.0, 'relationship between the total revenue earned by arcades and the number of Computer Science PhDs')
